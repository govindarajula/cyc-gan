# %% [markdown]
# <a href="https://colab.research.google.com/github/bkkaggle/pytorch-CycleGAN-and-pix2pix/blob/master/CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# ### exploring horse 2 zebra data with the full architecture, reimplementing BAIR research paper

# %%
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt

# %% [markdown]
# #### Dataset used here: horse2zebra
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh horse2zebra

# %% [markdown]
# #### We use the pretrained model for the same, to explore reimplementation. Parameters and architecture taken are same as the Cyc-GAN paper
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_cyclegan_model.sh horse2zebra
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [horse2zebra]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-03-08 03:19:22--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/horse2zebra.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.189.73
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.189.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/horse2zebra_pretrained/latest_net_G.pth’
#
# ./checkpoints/horse 100%[===================>]  43.46M  15.9MB/s    in 2.7s
#
# 2020-03-08 03:19:25 (15.9 MB/s) - ‘./checkpoints/horse2zebra_pretrained/latest_net_G.pth’ saved [45575747/45575747]

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan --n_epochs 100 --gan_mode 'wgangp'
#--niter 100
#--gpu_ids 0,1
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/horse2zebra        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: wgangp                        	[default: lsgan]
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: cycle_gan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: horse2zebra                   	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                   no_html: False
#                      norm: instance
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# The number of training images = 50
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 11.378 M
# [Network G_B] Total number of parameters : 11.378 M
# [Network D_A] Total number of parameters : 2.765 M
# [Network D_B] Total number of parameters : 2.765 M
# -----------------------------------------------
# Setting up a new session...
# Exception in user code:
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f33ae5f5208>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f33ae5f5208>: Failed to establish a new connection: [Errno 111] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 572, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f33ae5f5208>: Failed to establish a new connection: [Errno 111] Connection refused',))
# [Errno 111] Connection refused
#
#
# Could not connect to Visdom server.
#  Trying to start a server....
# Command: /home/ubuntu/anaconda3/bin/python -m visdom.server -p 8097 &>/dev/null &
# create web directory ./checkpoints/horse2zebra/web...
# End of epoch 1 / 200 	 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 2, iters: 50, time: 0.773, data: 0.198) D_A: -0.724 G_A: -0.197 cycle_A: 2.741 idt_A: 1.624 D_B: -0.919 G_B: -3.892 cycle_B: 3.372 idt_B: 1.223
# End of epoch 2 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# End of epoch 3 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 4, iters: 50, time: 0.775, data: 0.151) D_A: -0.227 G_A: -8.178 cycle_A: 2.768 idt_A: 1.449 D_B: -0.256 G_B: -3.436 cycle_B: 3.151 idt_B: 1.422
# End of epoch 4 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# saving the model at the end of epoch 5, iters 250
# End of epoch 5 / 200 	 Time Taken: 37 sec
# learning rate = 0.0002000
# (epoch: 6, iters: 50, time: 0.782, data: 0.129) D_A: -1.883 G_A: -16.547 cycle_A: 2.058 idt_A: 2.470 D_B: 0.629 G_B: -2.686 cycle_B: 4.632 idt_B: 0.735
# End of epoch 6 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# End of epoch 7 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 8, iters: 50, time: 1.170, data: 0.143) D_A: -12.894 G_A: -25.087 cycle_A: 4.300 idt_A: 1.962 D_B: -0.733 G_B: -5.185 cycle_B: 3.389 idt_B: 2.069
# End of epoch 8 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# End of epoch 9 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 10, iters: 50, time: 0.775, data: 0.152) D_A: -8.784 G_A: -34.449 cycle_A: 3.571 idt_A: 1.406 D_B: 1.638 G_B: -11.048 cycle_B: 3.019 idt_B: 1.684
# saving the model at the end of epoch 10, iters 500
# End of epoch 10 / 200 	 Time Taken: 37 sec
# learning rate = 0.0002000
# End of epoch 11 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 12, iters: 50, time: 0.774, data: 0.143) D_A: -47.516 G_A: -65.568 cycle_A: 4.767 idt_A: 3.293 D_B: -3.510 G_B: -6.731 cycle_B: 7.000 idt_B: 2.357
# End of epoch 12 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# End of epoch 13 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 14, iters: 50, time: 0.778, data: 0.129) D_A: -12.876 G_A: -73.891 cycle_A: 3.835 idt_A: 2.318 D_B: -12.381 G_B: -15.363 cycle_B: 4.551 idt_B: 1.740
# End of epoch 14 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# saving the model at the end of epoch 15, iters 750
# End of epoch 15 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch:
/ 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# End of epoch 99 / 200 	 Time Taken: 36 sec
# learning rate = 0.0002000
# (epoch: 100, iters: 50, time: 0.778, data: 0.145) D_A: -159.925 G_A: -498.884 cycle_A: 7.143 idt_A: 3.381 D_B: 106.264 G_B: -65.009 cycle_B: 6.270 idt_B: 3.472
# saving the latest model (epoch 100, total_iters 5000)
# saving the model at the end of epoch 100, iters 5000
# End of epoch 100 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001980
# End of epoch 101 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001960
# (epoch: 102, iters: 50, time: 0.780, data: 0.117) D_A: -192.303 G_A: -39.853 cycle_A: 3.339 idt_A: 2.406 D_B: -314.113 G_B: -280.377 cycle_B: 3.666 idt_B: 1.691
# End of epoch 102 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001941
# End of epoch 103 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001921
# (epoch: 104, iters: 50, time: 1.807, data: 0.143) D_A: -252.804 G_A: -621.538 cycle_A: 2.935 idt_A: 2.155 D_B: 1.752 G_B: -656.925 cycle_B: 4.206 idt_B: 1.530
# End of epoch 104 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001901
# saving the model at the end of epoch 105, iters 5250
# End of epoch 105 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001881
# (epoch: 106, iters: 50, time: 0.774, data: 0.154) D_A: -655.829 G_A: 537.112 cycle_A: 3.443 idt_A: 4.671 D_B: -27.141 G_B: -518.874 cycle_B: 9.411 idt_B: 1.381
# End of epoch 106 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001861
# End of epoch 107 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001842
# (epoch: 108, iters: 50, time: 0.777, data: 0.117) D_A: 89.397 G_A: -528.384 cycle_A: 3.836 idt_A: 2.711 D_B: -12.353 G_B: -405.266 cycle_B: 6.441 idt_B: 2.050
# End of epoch 108 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001822
# End of epoch 109 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001802
# (epoch: 110, iters: 50, time: 0.773, data: 0.129) D_A: -274.497 G_A: -216.274 cycle_A: 3.531 idt_A: 3.844 D_B: -18.867 G_B: -496.697 cycle_B: 7.676 idt_B: 1.774
# saving the model at the end of epoch 110, iters 5500
# End of epoch 110 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001782
# End of epoch 111 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001762
# (epoch: 112, iters: 50, time: 1.934, data: 0.141) D_A: 56.361 G_A: -706.346 cycle_A: 5.186 idt_A: 2.128 D_B: -337.492 G_B: -521.177 cycle_B: 4.423 idt_B: 2.089
# End of epoch 112 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001743
# End of epoch 113 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001723
# (epoch: 114, iters: 50, time: 0.779, data: 0.167) D_A: -123.194 G_A: -837.900 cycle_A: 3.617 idt_A: 2.950 D_B: -14.136 G_B: -613.905 cycle_B: 6.180 idt_B: 1.804
# End of epoch 114 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001703
# saving the model at the end of epoch 115, iters 5750
# End of epoch 115 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001683
# (epoch: 116, iters: 50, time: 0.773, data: 0.142) D_A: -130.843 G_A: -410.464 cycle_A: 5.911 idt_A: 3.194 D_B: -14.219 G_B: -625.439 cycle_B: 6.615 idt_B: 2.740
# End of epoch 116 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001663
# End of epoch 117 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001644
# (epoch: 118, iters: 50, time: 0.784, data: 0.141) D_A: -1.249 G_A: -708.464 cycle_A: 4.394 idt_A: 1.936 D_B: -7.433 G_B: -811.344 cycle_B: 3.667 idt_B: 2.021
# End of epoch 118 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001624
# End of epoch 119 / 200 	 Time Taken: 36 sec
# learning rate = 0.0
/ 200 	 Time Taken: 36 sec
# learning rate = 0.0001228
# End of epoch 139 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001208
# (epoch: 140, iters: 50, time: 0.778, data: 0.124) D_A: -29.494 G_A: -607.156 cycle_A: 5.214 idt_A: 2.572 D_B: 29.712 G_B: -712.294 cycle_B: 5.004 idt_B: 2.144
# saving the model at the end of epoch 140, iters 7000
# End of epoch 140 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001188
# End of epoch 141 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001168
# (epoch: 142, iters: 50, time: 0.777, data: 0.149) D_A: -64.970 G_A: -769.350 cycle_A: 7.434 idt_A: 2.688 D_B: 110.751 G_B: -385.970 cycle_B: 5.381 idt_B: 3.848
# End of epoch 142 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001149
# End of epoch 143 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001129
# (epoch: 144, iters: 50, time: 2.074, data: 0.116) D_A: 113.320 G_A: -846.295 cycle_A: 6.992 idt_A: 1.912 D_B: -38.895 G_B: -383.380 cycle_B: 4.229 idt_B: 3.444
# End of epoch 144 / 200 	 Time Taken: 37 sec
# learning rate = 0.0001109
# saving the model at the end of epoch 145, iters 7250
# End of epoch 145 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001089
# (epoch: 146, iters: 50, time: 0.776, data: 0.142) D_A: -203.198 G_A: -793.905 cycle_A: 3.759 idt_A: 2.294 D_B: -212.888 G_B: -359.540 cycle_B: 4.519 idt_B: 2.259
# End of epoch 146 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001069
# End of epoch 147 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001050
# (epoch: 148, iters: 50, time: 0.774, data: 0.118) D_A: -673.713 G_A: -815.463 cycle_A: 5.530 idt_A: 3.227 D_B: 187.146 G_B: -517.571 cycle_B: 6.322 idt_B: 2.854
# End of epoch 148 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001030
# End of epoch 149 / 200 	 Time Taken: 36 sec
# learning rate = 0.0001010
# (epoch: 150, iters: 50, time: 0.774, data: 0.125) D_A: 77.556 G_A: -948.316 cycle_A: 6.407 idt_A: 2.412 D_B: -342.433 G_B: -705.361 cycle_B: 4.603 idt_B: 3.104
# saving the model at the end of epoch 150, iters 7500
# End of epoch 150 / 200 	 Time Taken: 37 sec
# learning rate = 0.0000990
# End of epoch 151 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000970
# (epoch: 152, iters: 50, time: 2.216, data: 0.139) D_A: 10.145 G_A: -828.981 cycle_A: 3.716 idt_A: 2.597 D_B: -58.782 G_B: -629.479 cycle_B: 5.224 idt_B: 1.696
# End of epoch 152 / 200 	 Time Taken: 37 sec
# learning rate = 0.0000950
# End of epoch 153 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000931
# (epoch: 154, iters: 50, time: 0.780, data: 0.148) D_A: -622.968 G_A: -900.454 cycle_A: 6.502 idt_A: 2.842 D_B: 182.619 G_B: -478.131 cycle_B: 6.197 idt_B: 3.786
# End of epoch 154 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000911
# saving the model at the end of epoch 155, iters 7750
# End of epoch 155 / 200 	 Time Taken: 37 sec
# learning rate = 0.0000891
# (epoch: 156, iters: 50, time: 0.776, data: 0.142) D_A: -534.441 G_A: -805.667 cycle_A: 5.585 idt_A: 2.607 D_B: -700.578 G_B: -830.498 cycle_B: 5.630 idt_B: 2.811
# End of epoch 156 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000871
# End of epoch 157 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000851
# (epoch: 158, iters: 50, time: 0.778, data: 0.145) D_A: -357.667 G_A: -955.203 cycle_A: 6.479 idt_A: 2.443 D_B: 9.152 G_B: -856.930 cycle_B: 5.161 idt_B: 3.204
# End of epoch 158 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000832
# End of epoch 159 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000812
# (epoch: 160, iters: 50, time: 2.191, data: 0.126) D_A: -643.601 G_A: -842.949 cycle_A: 4.116 idt_A: 3.405 D_B: -63.303 G_B: -865.162 cycle_B: 6.634 idt_B: 2.055
# saving the model at the end of epoch 160, iters 8000
# End of epoch 160 / 200 	 Time Taken: 38 sec
# learning rate = 0.0000792
# End of epoch 161 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000772
# (epoch: 162, iters: 50, time: 0.777, data: 0.139) D_A: 9.022 G_A: -908.980 cycle_A: 5.449 idt_A: 2.145 D_B: 251.061 G_B: -741.300 cycle_B: 4.111 idt_B: 2.695
# End of epoch 162 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000752
# End of epoch 163 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000733
# (epoch: 164, iters: 50, time: 0.778, data: 0.147) D_A: -17.143 G_A: -905.023 cycle_A: 4.606 idt_A: 2.147 D_B: 59.312 G_B: -869.725 cycle_B: 4.292 idt_B: 2.298
# End of epoch 164 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000713
# saving the model at the end of epoch 165, iters 8250
# End of epoch 165 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000693
# (epoch: 166, iters: 50, time: 0.773, data: 0.118) D_A: -37.292 G_A: -1006.032 cycle_A: 3.020 idt_A: 2.738 D_B: -58.796 G_B: -803.630 cycle_B: 5.425 idt_B: 1.524
# End of epoch 166 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000673
# End of epoch 167 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000653
# (epoch: 168, iters: 50, time: 2.320, data: 0.146) D_A: -542.219 G_A: -987.071 cycle_A: 4.858 idt_A: 2.684 D_B: -250.303 G_B: -950.861 cycle_B: 5.053 idt_B: 1.930
# End of epoch 168 / 200 	 Time Taken: 38 sec
# learning rate = 0.0000634
# End of epoch 169 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000614
# (epoch: 170, iters: 50, time: 0.777, data: 0.128) D_A: 171.594 G_A: -734.436 cycle_A: 3.158 idt_A: 3.080 D_B: -484.485 G_B: -829.497 cycle_B: 6.091 idt_B: 1.419
# saving the model at the end of epoch 170, iters 8500
# End of epoch 170 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000594
# End of epoch 171 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000574
# (epoch: 172, iters: 50, time: 0.773, data: 0.143) D_A: -493.376 G_A: -971.197 cycle_A: 5.156 idt_A: 3.210 D_B: -665.939 G_B: -851.650 cycle_B: 6.173 idt_B: 2.080
# End of epoch 172 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000554
# End of epoch 173 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000535
# (epoch: 174, iters: 50, time: 0.775, data: 0.151) D_A: 115.523 G_A: -1085.869 cycle_A: 4.465 idt_A: 2.480 D_B: 31.586 G_B: -830.032 cycle_B: 4.936 idt_B: 2.041
# End of epoch 174 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000515
# saving the model at the end of epoch 175, iters 8750
# End of epoch 175 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000495
# (epoch: 176, iters: 50, time: 2.378, data: 0.121) D_A: -631.582 G_A: -697.117 cycle_A: 4.233 idt_A: 2.510 D_B: -20.042 G_B: -820.803 cycle_B: 4.722 idt_B: 2.226
# End of epoch 176 / 200 	 Time Taken: 37 sec
# learning rate = 0.0000475
# End of epoch 177 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000455
# (epoch: 178, iters: 50, time: 0.777, data: 0.121) D_A: 125.383 G_A: -831.154 cycle_A: 3.998 idt_A: 1.968 D_B: 70.728 G_B: -832.240 cycle_B: 3.780 idt_B: 1.994
# End of epoch 178 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000436
# End of epoch 179 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000416
# (epoch: 180, iters: 50, time: 0.773, data: 0.138) D_A: -95.650 G_A: -832.055 cycle_A: 4.442 idt_A: 3.596 D_B: 135.967 G_B: -893.183 cycle_B: 7.247 idt_B: 2.257
# saving the model at the end of epoch 180, iters 9000
# End of epoch 180 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000396
# End of epoch 181 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000376
# (epoch: 182, iters: 50, time: 0.778, data: 0.134) D_A: -878.787 G_A: -1086.978 cycle_A: 6.459 idt_A: 2.600 D_B: 46.175 G_B: -954.189 cycle_B: 5.419 idt_B: 2.893
# End of epoch 182 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000356
# End of epoch 183 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000337
# (epoch: 184, iters: 50, time: 2.671, data: 0.148) D_A: -192.988 G_A: -612.022 cycle_A: 3.131 idt_A: 2.863 D_B: -112.595 G_B: -817.833 cycle_B: 5.677 idt_B: 1.514
# End of epoch 184 / 200 	 Time Taken: 38 sec
# learning rate = 0.0000317
# saving the model at the end of epoch 185, iters 9250
# End of epoch 185 / 200 	 Time Taken: 37 sec
# learning rate = 0.0000297
# (epoch: 186, iters: 50, time: 0.776, data: 0.135) D_A: -39.913 G_A: -913.538 cycle_A: 6.604 idt_A: 3.453 D_B: -713.666 G_B: -916.388 cycle_B: 6.975 idt_B: 2.934
# End of epoch 186 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000277
# End of epoch 187 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000257
# (epoch: 188, iters: 50, time: 0.777, data: 0.120) D_A: -792.783 G_A: -1059.060 cycle_A: 4.907 idt_A: 2.043 D_B: -438.279 G_B: -963.487 cycle_B: 4.304 idt_B: 2.450
# End of epoch 188 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000238
# End of epoch 189 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000218
# (epoch: 190, iters: 50, time: 0.776, data: 0.124) D_A: -12.256 G_A: -915.160 cycle_A: 5.218 idt_A: 2.954 D_B: -28.002 G_B: -886.347 cycle_B: 5.583 idt_B: 1.997
# saving the model at the end of epoch 190, iters 9500
# End of epoch 190 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000198
# End of epoch 191 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000178
# (epoch: 192, iters: 50, time: 2.518, data: 0.142) D_A: -424.672 G_A: -1007.605 cycle_A: 6.492 idt_A: 3.394 D_B: 38.468 G_B: -917.283 cycle_B: 6.795 idt_B: 2.085
# End of epoch 192 / 200 	 Time Taken: 38 sec
# learning rate = 0.0000158
# End of epoch 193 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000139
# (epoch: 194, iters: 50, time: 0.779, data: 0.155) D_A: -30.597 G_A: -892.562 cycle_A: 6.274 idt_A: 2.626 D_B: 41.754 G_B: -927.616 cycle_B: 5.421 idt_B: 3.021
# End of epoch 194 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000119
# saving the model at the end of epoch 195, iters 9750
# End of epoch 195 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000099
# (epoch: 196, iters: 50, time: 0.777, data: 0.138) D_A: -81.181 G_A: -934.018 cycle_A: 4.292 idt_A: 2.903 D_B: -404.776 G_B: -880.162 cycle_B: 5.522 idt_B: 1.833
# End of epoch 196 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000079
# End of epoch 197 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000059
# (epoch: 198, iters: 50, time: 0.776, data: 0.148) D_A: -1.858 G_A: -892.618 cycle_A: 5.976 idt_A: 2.786 D_B: 12.530 G_B: -827.402 cycle_B: 5.755 idt_B: 2.387
# End of epoch 198 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000040
# End of epoch 199 / 200 	 Time Taken: 36 sec
# learning rate = 0.0000020
# (epoch: 200, iters: 50, time: 2.466, data: 0.140) D_A: -118.670 G_A: -860.862 cycle_A: 5.035 idt_A: 3.092 D_B: 229.765 G_B: -889.814 cycle_B: 6.649 idt_B: 2.248
# saving the latest model (epoch 200, total_iters 10000)
# saving the model at the end of epoch 200, iters 10000
# End of epoch 200 / 200 	 Time Taken: 39 sec
# learning rate = 0.0000000

# %% [markdown]
# ### Testing
#
# By default, we have single mode to load the images. Using --model cycle_gan will automatically load & generate the results in both directions, which is not always necessary.
#
# Other experiments and results generated for training against our dataset include modifications or specifying --norm, --netG, dropout etc. Another implementation against the vgg content_loss instead of the standard pixel loss has been done. It can be explored in the AMI in corresponding folder & ipynb files to check its results.
#
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
# !python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/horse2zebra/testA    	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: horse2zebra_pretrained        	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: instance
#                     ntest: inf
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/horse2zebra_pretrained/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 11.378 M
# -----------------------------------------------
# creating web directory ./results/horse2zebra_pretrained/test_latest
# processing (0000)-th image... ['datasets/horse2zebra/testA/n02381460_1000.jpg']
# processing (0005)-th image... ['datasets/horse2zebra/testA/n02381460_1110.jpg']
# processing (0010)-th image... ['datasets/horse2zebra/testA/n02381460_1260.jpg']
# processing (0015)-th image... ['datasets/horse2zebra/testA/n02381460_1420.jpg']
# processing (0020)-th image... ['datasets/horse2zebra/testA/n02381460_1690.jpg']
# processing (0025)-th image... ['datasets/horse2zebra/testA/n02381460_1830.jpg']
# processing (0030)-th image... ['datasets/horse2zebra/testA/n02381460_2050.jpg']
# processing (0035)-th image... ['datasets/horse2zebra/testA/n02381460_2460.jpg']
# processing (0040)-th image... ['datasets/horse2zebra/testA/n02381460_2870.jpg']
# processing (0045)-th image... ['datasets/horse2zebra/testA/n02381460_3040.jpg']

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png')
plt.imshow(img)

# %%
img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_3330_real.png')
plt.imshow(img)

# %%
img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_3330_fake.png')
plt.imshow(img)
